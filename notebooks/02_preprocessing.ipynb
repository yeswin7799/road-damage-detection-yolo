# %%
from pathlib import Path
import os

# Where we will store YOLO-ready data
YOLO_DIR = Path(r"D:\MachineLearingProject\YOLODataset")

# Create folders
for sub in ["images/train", "images/val", "labels/train", "labels/val"]:
    path = YOLO_DIR / sub
    path.mkdir(parents=True, exist_ok=True)

YOLO_DIR
# Out:
# WindowsPath('D:/MachineLearingProject/YOLODataset')

# %%
BASE_DIR = Path(r"D:\MachineLearingProject\RDD2022")

# Get country folders again
countries = [d for d in BASE_DIR.iterdir() if d.is_dir()]

countries
# Out:
# [WindowsPath('D:/MachineLearingProject/RDD2022/China_Drone'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/China_MotorBike'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/Czech'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/India'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/Japan'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/Norway'),
#  WindowsPath('D:/MachineLearingProject/RDD2022/United_States')]

# %%
# Mapping VOC damage labels → YOLO class IDs
CLASS_MAPPING = {
    "D00": 0,
    "D10": 1,
    "D20": 2,
    "D40": 3,
    "D44": 4
}

CLASS_MAPPING
# Out:
# {'D00': 0, 'D10': 1, 'D20': 2, 'D40': 3, 'D44': 4}

# %%
import xml.etree.ElementTree as ET
import shutil
import cv2

def convert_xml_to_yolo(xml_file, img_file, label_output_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    # Image size from XML
    img_width = int(root.find("size/width").text)
    img_height = int(root.find("size/height").text)

    lines = []

    for obj in root.findall("object"):
        label = obj.find("name").text
        
        if label not in CLASS_MAPPING:
            continue   # skip unknown classes
        
        class_id = CLASS_MAPPING[label]

        bbox = obj.find("bndbox")
        
        xmin = float(bbox.find("xmin").text)
        ymin = float(bbox.find("ymin").text)
        xmax = float(bbox.find("xmax").text)
        ymax = float(bbox.find("ymax").text)

        # Convert to YOLO format
        x_center = (xmin + xmax) / 2 / img_width
        y_center = (ymin + ymax) / 2 / img_height
        width = (xmax - xmin) / img_width
        height = (ymax - ymin) / img_height

        lines.append(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")

    # Write YOLO TXT file
    with open(label_output_file, "w") as f:
        f.write("\n".join(lines))

# %%
import random
random.seed(42)

def split_data(file_list, train_ratio=0.9):
    random.shuffle(file_list)
    train_count = int(len(file_list) * train_ratio)
    return file_list[:train_count], file_list[train_count:]

# %%
def process_country(country):
    print("Processing:", country)

    image_dir = BASE_DIR / country / "train" / "images"
    xml_dir   = BASE_DIR / country / "train" / "annotations" / "xmls"

    image_files = list(image_dir.glob("*.jpg"))

    train_files, val_files = split_data(image_files, train_ratio=0.9)

    # Process train files
    for img_file in train_files:
        xml_file = xml_dir / (img_file.stem + ".xml")
        label_file = YOLO_DIR / "labels/train" / (img_file.stem + ".txt")
        out_img_file = YOLO_DIR / "images/train" / img_file.name

        shutil.copy(img_file, out_img_file)
        convert_xml_to_yolo(xml_file, img_file, label_file)

    # Process val files
    for img_file in val_files:
        xml_file = xml_dir / (img_file.stem + ".xml")
        label_file = YOLO_DIR / "labels/val" / (img_file.stem + ".txt")
        out_img_file = YOLO_DIR / "images/val" / img_file.name

        shutil.copy(img_file, out_img_file)
        convert_xml_to_yolo(xml_file, img_file, label_file)

for country_dir in countries:
    process_country(country_dir.name)

print("YOLO dataset created successfully!")
# Out:
# Processing: China_Drone
# Processing: China_MotorBike
# Processing: Czech
# Processing: India
# Processing: Japan
# Processing: Norway
# Processing: United_States
# YOLO dataset created successfully!

# %%
yaml_content = f"""
train: {YOLO_DIR}/images/train
val: {YOLO_DIR}/images/val

nc: 5
names: ['D00', 'D10', 'D20', 'D40', 'D44']
"""

with open(YOLO_DIR / "dataset.yaml", "w") as f:
    f.write(yaml_content)

print("dataset.yaml created!")
# Out:
# dataset.yaml created!

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import ultralytics
#       2 ultralytics.checks()
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.3.228-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\app\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\app\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\app\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\app\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\app\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\app\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\app\lib\site-packages (from ultralytics) (1.15.3)
# Collecting torch>=1.8.0 (from ultralytics)
#   Using cached torch-2.9.1-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.24.1-cp313-cp313-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: psutil in c:\app\lib\site-packages (from ultralytics) (6.1.1)
# Collecting polars (from ultralytics)
#   Using cached polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\app\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\app\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\app\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\app\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\app\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\app\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\app\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Collecting networkx>=2.5.1 (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\app\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\app\lib\site-packages (from torch>=1.8.0->ultralytics) (75.7.0)
# Collecting polars-runtime-32==1.35.2 (from polars->ultralytics)
#   Using cached polars_runtime_32-1.35.2-cp39-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in c:\app\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\app\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\app\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Using cached ultralytics-8.3.228-py3-none-any.whl (1.1 MB)
# Using cached torch-2.9.1-cp313-cp313-win_amd64.whl (110.9 MB)
# Using cached torchvision-0.24.1-cp313-cp313-win_amd64.whl (4.3 MB)
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Using cached polars-1.35.2-py3-none-any.whl (783 kB)
# Using cached polars_runtime_32-1.35.2-cp39-abi3-win_amd64.whl (41.3 MB)
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Installing collected packages: polars-runtime-32, networkx, fsspec, filelock, torch, polars, ultralytics-thop, torchvision, ultralytics
# Successfully installed filelock-3.20.0 fsspec-2025.10.0 networkx-3.5 polars-1.35.2 polars-runtime-32-1.35.2 torch-2.9.1 torchvision-0.24.1 ultralytics-8.3.228 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: C:\App\python.exe -m pip install --upgrade pip

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.228  Python-3.13.0 torch-2.9.1+cpu CPU (Intel Core i7-9750H 2.60GHz)
# Setup complete  (12 CPUs, 31.7 GB RAM, 336.0/1863.0 GB disk)

# %%
from ultralytics import YOLO

# Load YOLO Nano model (fastest)
model = YOLO("yolov8n.pt")

# Train the model
model.train(
    data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
    epochs=5,
    imgsz=384,
    batch=4,
    name="road_damage_detector"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 27.3MB/s 0.2s.2s<0.0s.8s
# Ultralytics 8.3.228  Python-3.13.0 torch-2.9.1+cpu CPU (Intel Core i7-9750H 2.60GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\MachineLearingProject\YOLODataset\dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\MachineLearingProject\runs\detect\road_damage_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\chintapalli\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 6.5MB/s 0.1s 0.1s<0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 13.815.5 ms, read: 6.48.6 MB/s, size: 325.6 KB)
# train: Scanning D:\MachineLearingProject\YOLODataset\labels\train... 34543 images, 11851 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34543/34543 58.1it/s 9:54<0.3ss
# train: New cache created: D:\MachineLearingProject\YOLODataset\labels\train.cache
# val: Fast image access  (ping: 5.06.7 ms, read: 6.39.4 MB/s, size: 374.3 KB)
# val: Scanning D:\MachineLearingProject\YOLODataset\labels\val... 3842 images, 1303 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3842/3842 131.5it/s 29.2s<0.1s
# val: New cache created: D:\MachineLearingProject\YOLODataset\labels\val.cache
# Plotting labels to D:\MachineLearingProject\runs\detect\road_damage_detector\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\MachineLearingProject\runs\detect\road_damage_detector
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      2.076      3.848      1.792         11        640: 100% ━━━━━━━━━━━━ 4318/4318 2.9s/it 3:25:11<2.7ss5
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 241/241 2.0s/it 8:06<2.1s
#                    all       3842       6126      0.277      0.249      0.176     0.0712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      2.019      2.901      1.749         28        640: 100% ━━━━━━━━━━━━ 4318/4318 2.8s/it 3:23:38<2.6ss3
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 241/241 2.3s/it 9:06<2.2s
#                    all       3842       6126      0.323      0.289      0.235      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      2.139       2.77      1.781         17        640: 0% ──────────── 9/4318 1.5s/it 30.4s<1:49:494
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 7
#       4 model = YOLO("yolov8n.pt")
#       6 # Train the model
# ----> 7 model.train(
#       8     data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
#       9     epochs=20,
#      10     imgsz=640,
#      11     batch=8,
#      12     name="road_damage_detector"
#      13 )
#
# File C:\App\Lib\site-packages\ultralytics\engine\model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:427, in BaseTrainer._do_train(self)
#     425     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     426 else:
# --> 427     loss, self.loss_items = self.model(batch)
#     428 self.loss = loss.sum()
#     429 if RANK != -1:
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File C:\App\Lib\site-packages\ultralytics\nn\tasks.py:136, in BaseModel.forward(self, x, *args, **kwargs)
#     123 """Perform forward pass of the model for either training or inference.
#     124
#     125 If x is a dict, calculates and returns the loss for training. Otherwise, returns predictions for inference.
#    (...)
#     133     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     134 """
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 136     return self.loss(x, *args, **kwargs)
#     137 return self.predict(x, *args, **kwargs)
#
# File C:\App\Lib\site-packages\ultralytics\nn\tasks.py:327, in BaseModel.loss(self, batch, preds)
#     324     self.criterion = self.init_criterion()
#     326 if preds is None:
# --> 327     preds = self.forward(batch["img"])
#     328 return self.criterion(preds, batch)
#
# File C:\App\Lib\site-packages\ultralytics\nn\tasks.py:137, in BaseModel.forward(self, x, *args, **kwargs)
#     135 if isinstance(x, dict):  # for cases of training and validating while training.
#     136     return self.loss(x, *args, **kwargs)
# --> 137 return self.predict(x, *args, **kwargs)
#
# File C:\App\Lib\site-packages\ultralytics\nn\tasks.py:154, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     152 if augment:
#     153     return self._predict_augment(x)
# --> 154 return self._predict_once(x, profile, visualize, embed)
#
# File C:\App\Lib\site-packages\ultralytics\nn\tasks.py:176, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     174 if profile:
#     175     self._profile_one_layer(m, x, dt)
# --> 176 x = m(x)  # run
#     177 y.append(x if m.i in self.save else None)  # save output
#     178 if visualize:
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File C:\App\Lib\site-packages\ultralytics\nn\modules\conv.py:78, in Conv.forward(self, x)
#      69 def forward(self, x):
#      70     """Apply convolution, batch normalization and activation to input tensor.
#      71
#      72     Args:
#    (...)
#      76         (torch.Tensor): Output tensor.
#      77     """
# ---> 78     return self.act(self.bn(self.conv(x)))
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File C:\App\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File C:\App\Lib\site-packages\torch\nn\modules\batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     (
#     197         self.running_mean
#     198         if not self.training or self.track_running_stats
#     199         else None
#     200     ),
#     201     self.running_var if not self.training or self.track_running_stats else None,
#     202     self.weight,
#     203     self.bias,
#     204     bn_training,
#     205     exponential_average_factor,
#     206     self.eps,
#     207 )
#
# File C:\App\Lib\site-packages\torch\nn\functional.py:2813, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2810 if training:
#    2811     _verify_batch_size(input.size())
# -> 2813 return torch.batch_norm(
#    2814     input,
#    2815     weight,
#    2816     bias,
#    2817     running_mean,
#    2818     running_var,
#    2819     training,
#    2820     momentum,
#    2821     eps,
#    2822     torch.backends.cudnn.enabled,
#    2823 )
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/road_damage_detector/weights/last.pt")

model.train(
    data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
    resume=True
)
# Out:
# Ultralytics 8.3.228  Python-3.13.0 torch-2.9.1+cpu CPU (Intel Core i7-9750H 2.60GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\MachineLearingProject\YOLODataset\dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs\detect\road_damage_detector\weights\last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=runs\detect\road_damage_detector\weights\last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\MachineLearingProject\runs\detect\road_damage_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 17.03.1 ms, read: 11.215.4 MB/s, size: 325.6 KB)
# train: Scanning D:\MachineLearingProject\YOLODataset\labels\train.cache... 34543 images, 11851 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34543/34543 60.8Mit/s 0.0s
# val: Fast image access  (ping: 16.513.6 ms, read: 7.19.8 MB/s, size: 374.3 KB)
# val: Scanning D:\MachineLearingProject\YOLODataset\labels\val.cache... 3842 images, 1303 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3842/3842 5.0Mit/s 0.0s
# Plotting labels to D:\MachineLearingProject\runs\detect\road_damage_detector\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training runs\detect\road_damage_detector\weights\last.pt from epoch 3 to 20 total epochs
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\MachineLearingProject\runs\detect\road_damage_detector
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      2.024      2.689      1.781         13        640: 1% ──────────── 45/4318 2.7s/it 2:10<3:15:471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 from ultralytics import YOLO
#       3 model = YOLO("runs/detect/road_damage_detector/weights/last.pt")
# ----> 5 model.train(
#       6     data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
#       7     resume=True
#       8 )
#
# File C:\App\Lib\site-packages\ultralytics\engine\model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:434, in BaseTrainer._do_train(self)
#     431     self.tloss = self.loss_items if self.tloss is None else (self.tloss * i + self.loss_items) / (i + 1)
#     433 # Backward
# --> 434 self.scaler.scale(self.loss).backward()
#     435 if ni - last_opt_step >= self.accumulate:
#     436     self.optimizer_step()
#
# File C:\App\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)
#     623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File C:\App\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File C:\App\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model.train(
    data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
    epochs=5,
    imgsz=384,
    batch=4,
    resume=True,
    name="road_damage_cpu_fast"
)
# Out:
# Ultralytics 8.3.228  Python-3.13.0 torch-2.9.1+cpu CPU (Intel Core i7-9750H 2.60GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\MachineLearingProject\YOLODataset\dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=384, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs\detect\road_damage_detector\weights\last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=runs\detect\road_damage_detector\weights\last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\MachineLearingProject\runs\detect\road_damage_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 205.2217.5 MB/s, size: 501.9 KB)
# train: Scanning D:\MachineLearingProject\YOLODataset\labels\train.cache... 34543 images, 11851 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34543/34543 45.1Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 352.3451.5 MB/s, size: 378.4 KB)
# val: Scanning D:\MachineLearingProject\YOLODataset\labels\val.cache... 3842 images, 1303 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3842/3842 5.8Mit/s 0.0s
# Plotting labels to D:\MachineLearingProject\runs\detect\road_damage_detector\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training runs\detect\road_damage_detector\weights\last.pt from epoch 3 to 20 total epochs
# Image sizes 384 train, 384 val
# Using 0 dataloader workers
# Logging results to D:\MachineLearingProject\runs\detect\road_damage_detector
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      2.306      3.075      1.765          9        384: 3% ──────────── 297/8636 1.9it/s 3:08<1:12:042
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model.train(
#       2     data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
#       3     epochs=5,
#       4     imgsz=384,
#       5     batch=4,
#       6     resume=True,
#       7     name="road_damage_cpu_fast"
#       8 )
#
# File C:\App\Lib\site-packages\ultralytics\engine\model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File C:\App\Lib\site-packages\ultralytics\engine\trainer.py:404, in BaseTrainer._do_train(self)
#     402     pbar = TQDM(enumerate(self.train_loader), total=nb)
#     403 self.tloss = None
# --> 404 for i, batch in pbar:
#     405     self.run_callbacks("on_train_batch_start")
#     406     # Warmup
#
# File C:\App\Lib\site-packages\ultralytics\utils\tqdm.py:351, in TQDM.__iter__(self)
#     348     raise TypeError("'NoneType' object is not iterable")
#     350 try:
# --> 351     for item in self.iterable:
#     352         yield item
#     353         self.update(1)
#
# File C:\App\Lib\site-packages\ultralytics\data\build.py:76, in InfiniteDataLoader.__iter__(self)
#      74 """Create an iterator that yields indefinitely from the underlying iterator."""
#      75 for _ in range(len(self)):
# ---> 76     yield next(self.iterator)
#
# File C:\App\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File C:\App\Lib\site-packages\torch\utils\data\dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File C:\App\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File C:\App\Lib\site-packages\ultralytics\data\base.py:374, in BaseDataset.__getitem__(self, index)
#     372 def __getitem__(self, index: int) -> dict[str, Any]:
#     373     """Return transformed label information for given index."""
# --> 374     return self.transforms(self.get_image_and_label(index))
#
# File C:\App\Lib\site-packages\ultralytics\data\base.py:387, in BaseDataset.get_image_and_label(self, index)
#     385 label = deepcopy(self.labels[index])  # requires deepcopy() https://github.com/ultralytics/ultralytics/pull/1948
#     386 label.pop("shape", None)  # shape is for rect, remove it
# --> 387 label["img"], label["ori_shape"], label["resized_shape"] = self.load_image(index)
#     388 label["ratio_pad"] = (
#     389     label["resized_shape"][0] / label["ori_shape"][0],
#     390     label["resized_shape"][1] / label["ori_shape"][1],
#     391 )  # for evaluation
#     392 if self.rect:
#
# File C:\App\Lib\site-packages\ultralytics\data\base.py:233, in BaseDataset.load_image(self, i, rect_mode)
#     231         im = imread(f, flags=self.cv2_flag)  # BGR
#     232 else:  # read image
# --> 233     im = imread(f, flags=self.cv2_flag)  # BGR
#     234 if im is None:
#     235     raise FileNotFoundError(f"Image Not Found {f}")
#
# File C:\App\Lib\site-packages\ultralytics\utils\patches.py:42, in imread(filename, flags)
#      40     return None
#      41 else:
# ---> 42     im = cv2.imdecode(file_bytes, flags)
#      43     return im[..., None] if im is not None and im.ndim == 2 else im
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO

# Load the last checkpoint as pretrained weights
model = YOLO("runs/detect/road_damage_detector/weights/last.pt")

# Start a NEW training run using these weights
model.train(
    data=r"D:\MachineLearingProject\YOLODataset\dataset.yaml",
    epochs=5,
    imgsz=384,
    batch=4,
    name="road_damage_cpu_fast"
)
# Out:
# Ultralytics 8.3.228  Python-3.13.0 torch-2.9.1+cpu CPU (Intel Core i7-9750H 2.60GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=D:\MachineLearingProject\YOLODataset\dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=5, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=384, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/road_damage_detector/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_cpu_fast, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=D:\MachineLearingProject\runs\detect\road_damage_cpu_fast, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# Model summary: 129 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 1339.3972.4 MB/s, size: 501.9 KB)
# train: Scanning D:\MachineLearingProject\YOLODataset\labels\train.cache... 34543 images, 11851 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34543/34543 46.1Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 642.7592.4 MB/s, size: 378.4 KB)
# val: Scanning D:\MachineLearingProject\YOLODataset\labels\val.cache... 3842 images, 1303 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3842/3842 4.9Mit/s 0.0s
# Plotting labels to D:\MachineLearingProject\runs\detect\road_damage_cpu_fast\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 384 train, 384 val
# Using 0 dataloader workers
# Logging results to D:\MachineLearingProject\runs\detect\road_damage_cpu_fast
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      2.229       3.09       1.76          4        384: 2% ──────────── 146/8636 1.5it/s 1:34<1:34:12

# %%
from ultralytics import YOLO

model = YOLO(
    r"D:\MachineLearingProject\runs\detect\road_damage_cpu_fast\weights\best.pt"
)

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %%
results = model.predict(
    source=r"D:\MachineLearingProject\test_images\road2.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 D:\MachineLearingProject\test_images\road2.jpg: 384x384 (no detections), 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to D:\MachineLearingProject\runs\detect\predict

# %%
from ultralytics import YOLO

model = YOLO(r"D:\MachineLearingProject\runs\detect\road_damage_cpu_fast\weights\best.pt")

results = model.predict(
    source=r"D:\MachineLearingProject\test_images\road2.jpg",
    save=True,
    conf=0.10    # lower confidence for better detection
)
# Out:
# image 1/1 D:\MachineLearingProject\test_images\road2.jpg: 384x384 1 D10, 1 D20, 47.7ms
# Speed: 2.3ms preprocess, 47.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to D:\MachineLearingProject\runs\detect\predict5

# %%
results = model.predict(
    source=r"D:\MachineLearingProject\test_images\road2.jpg",
    save=True,
    conf=0.10
)
# Out:
# image 1/1 D:\MachineLearingProject\test_images\road2.jpg: 384x384 1 D10, 1 D20, 115.6ms
# Speed: 2.8ms preprocess, 115.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to D:\MachineLearingProject\runs\detect\predict5

# %%
model.predict(
    source=r"D:\MachineLearingProject\test_images\road3.webp",
    save=True,
    conf=0.10
)
# Out:
# image 1/1 D:\MachineLearingProject\test_images\road3.webp: 256x384 1 D44, 92.9ms
# Speed: 4.4ms preprocess, 92.9ms inference, 10.9ms postprocess per image at shape (1, 3, 256, 384)
# Results saved to D:\MachineLearingProject\runs\detect\predict6
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'D00', 1: 'D10', 2: 'D20', 3: 'D40', 4: 'D44'}
#  obb: None
#  orig_img: array([[[ 14,  16,  11],
#          [ 14,  16,  11],
#          [ 14,  16,  11],
#          ...,
#          [ 13,  14,  11],
#          [ 13,  14,  11],
#          [ 13,  14,  11]],
#
#         [[ 14,  16,  11],
#          [ 14,  16,  11],
#          [ 14,  16,  11],
#          ...,
#          [ 10,  11,   9],
#          [ 10,  11,   9],
#          [ 10,  11,   9]],
#
#         [[ 14,  16,  11],
#          [ 14,  16,  11],
#          [ 14,  16,  11],
#          ...,
#          [ 10,  11,   9],
#          [ 10,  11,   9],
#          [ 10,  11,   9]],
#
#         ...,
#
#         [[ 87,  78,  63],
#          [101,  92,  77],
#          [121, 111,  94],
#          ...,
#          [124, 119, 100],
#          [131, 126, 107],
#          [143, 138, 118]],
#
#         [[ 89,  78,  62],
#          [106,  94,  75],
#          [129, 115,  95],
#          ...,
#          [138, 134, 112],
#          [145, 141, 119],
#          [158, 154, 132]],
#
#         [[ 91,  79,  60],
#          [107,  92,  74],
#          [127, 111,  91],
#          ...,
#          [153, 150, 126],
#          [153, 150, 126],
#          [160, 157, 133]]], shape=(408, 612, 3), dtype=uint8)
#  orig_shape: (408, 612)
#  path: 'D:\\MachineLearingProject\\test_images\\road3.webp'
#  probs: None
#  save_dir: 'D:\\MachineLearingProject\\runs\\detect\\predict6'
#  speed: {'preprocess': 4.444299964234233, 'inference': 92.89249998982996, 'postprocess': 10.862399940378964}]

# %%
model.predict(
    source=r"D:\MachineLearingProject\samples\road2.jpg",
    save=True,
    conf=0.1
)
# Out:
# image 1/1 D:\MachineLearingProject\samples\road2.jpg: 384x384 1 D10, 1 D20, 50.5ms
# Speed: 3.7ms preprocess, 50.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to D:\MachineLearingProject\notebooks\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'D00', 1: 'D10', 2: 'D20', 3: 'D40', 4: 'D44'}
#  obb: None
#  orig_img: array([[[223, 228, 227],
#          [227, 232, 231],
#          [224, 229, 228],
#          ...,
#          [217, 213, 212],
#          [218, 214, 213],
#          [216, 212, 211]],
#
#         [[224, 229, 228],
#          [226, 231, 230],
#          [222, 227, 226],
#          ...,
#          [216, 212, 211],
#          [217, 213, 212],
#          [215, 211, 210]],
#
#         [[224, 229, 228],
#          [224, 229, 228],
#          [219, 224, 223],
#          ...,
#          [215, 211, 210],
#          [217, 213, 212],
#          [215, 211, 210]],
#
#         ...,
#
#         [[142, 130, 124],
#          [143, 131, 125],
#          [144, 132, 126],
#          ...,
#          [145, 133, 127],
#          [141, 129, 123],
#          [139, 127, 121]],
#
#         [[146, 134, 128],
#          [146, 134, 128],
#          [147, 135, 129],
#          ...,
#          [147, 135, 129],
#          [139, 127, 121],
#          [133, 121, 115]],
#
#         [[147, 135, 129],
#          [145, 133, 127],
#          [144, 132, 126],
#          ...,
#          [156, 144, 138],
#          [146, 134, 128],
#          [138, 126, 120]]], shape=(1024, 1024, 3), dtype=uint8)
#  orig_shape: (1024, 1024)
#  path: 'D:\\MachineLearingProject\\samples\\road2.jpg'
#  probs: None
#  save_dir: 'D:\\MachineLearingProject\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 3.6747000413015485, 'inference': 50.53759994916618, 'postprocess': 4.580300068482757}]

# %%
results = model.predict(
    source=r"D:\MachineLearingProject\samples\road2.jpg",
    conf=0.1,
    save=True
)

print(results[0].boxes.cls)   # class IDs
print(results[0].boxes.conf)  # confidence scor
# Out:
# image 1/1 D:\MachineLearingProject\samples\road2.jpg: 384x384 1 D10, 1 D20, 32.0ms
# Speed: 1.7ms preprocess, 32.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to D:\MachineLearingProject\notebooks\runs\detect\predict
# tensor([1., 2.])
# tensor([0.1616, 0.1023])
